# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LinearRegression, LogisticRegression, LassoCV, RidgeCV, Lasso, Ridge
from sklearn import metrics
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor 
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.ensemble import BaggingClassifier, BaggingRegressor
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.ensemble import GradientBoostingClassifier, AdaBoostClassifier, AdaBoostRegressor, VotingClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV, train_test_split, StratifiedKFold

from sklearn.svm import LinearSVC, SVC, SVR

# %%
df = pd.read_csv('../data/clean_data.csv')

# %%
df_model = df

# %%
df_model.head()
# Out:
#   country  year         region  protestnumber  startday  startmonth  \
# 0  Canada  1990  North America              1      15.0         1.0
# 1  Canada  1990  North America              2      25.0         6.0
# 2  Canada  1990  North America              3       1.0         7.0
# 3  Canada  1990  North America              4      12.0         7.0
# 4  Canada  1990  North America              5      14.0         8.0
#
#    startyear  endday  endmonth  endyear  ...  labor wage dispute  \
# 0     1990.0    15.0       1.0   1990.0  ...                   1
# 1     1990.0    25.0       6.0   1990.0  ...                   0
# 2     1990.0     1.0       7.0   1990.0  ...                   0
# 3     1990.0     6.0       9.0   1990.0  ...                   0
# 4     1990.0    15.0       8.0   1990.0  ...                   0
#
#    land farm issue police brutality political behavior, process  \
# 0                0                0                           1
# ...

# %% [markdown]
# ### Dropped Unnamed Column

# %%
#df_model.drop(columns = 'Unnamed: 0', inplace = True)

# %%
df_model.head()
# Out:
#   country  year         region  protestnumber  startday  startmonth  \
# 0  Canada  1990  North America              1      15.0         1.0
# 1  Canada  1990  North America              2      25.0         6.0
# 2  Canada  1990  North America              3       1.0         7.0
# 3  Canada  1990  North America              4      12.0         7.0
# 4  Canada  1990  North America              5      14.0         8.0
#
#    startyear  endday  endmonth  endyear  ...  labor wage dispute  \
# 0     1990.0    15.0       1.0   1990.0  ...                   1
# 1     1990.0    25.0       6.0   1990.0  ...                   0
# 2     1990.0     1.0       7.0   1990.0  ...                   0
# 3     1990.0     6.0       9.0   1990.0  ...                   0
# 4     1990.0    15.0       8.0   1990.0  ...                   0
#
#    land farm issue police brutality political behavior, process  \
# 0                0                0                           1
# ...

# %%
df_model.columns
# Out:
# Index(['country', 'year', 'region', 'protestnumber', 'startday', 'startmonth',
#        'startyear', 'endday', 'endmonth', 'endyear', 'protesterviolence',
#        'participants', 'notes', 'stateresponse', 'labor wage dispute',
#        'land farm issue', 'police brutality', 'political behavior, process',
#        'price increases, tax policy', 'removal of politician',
#        'social restrictions', 'startdate', 'enddate', 'duration'],
#       dtype='object')

# %%
X.columns
# Out:
# Index(['year', 'protestnumber', 'startday', 'startmonth', 'startyear',
#        'endday', 'endmonth', 'endyear', 'protesterviolence', 'participants',
#        'labor wage dispute', 'land farm issue', 'police brutality',
#        'political behavior, process', 'price increases, tax policy',
#        'removal of politician', 'social restrictions'],
#       dtype='object')

# %% [markdown]
# country, region, startdate , end date duration --- not included
# - startdate - end date didnt merge (didnt want to mess it up)
#
# not including for now just to get a better sense of which models to focus on

# %% [markdown]
# ## Baseline

# %%
df_model['stateresponse'].value_counts(normalize = True)
# Out:
# ignore             0.530883
# crowd dispersal    0.174036
# arrests            0.101285
# accomodation       0.069918
# killings           0.052992
# beatings           0.042490
# shootings          0.028396
# Name: stateresponse, dtype: float64

# %%
# need to beat 53%

# %% [markdown]
# ###  Define X and y variables

# %%
X = df_model._get_numeric_data()

# %%
y = df_model['stateresponse']

# %%
# might have to remap for modeling purposes

# %% [markdown]
# #### Train Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %% [markdown]
# #### Scale

# %%
ss = StandardScaler()
X_train_sc = ss.fit_transform(X_train)
X_test_sc = ss.transform(X_test)

# %% [markdown]
# ### Basic Models

# %%
abc = AdaBoostClassifier()
bc = BaggingClassifier()
rfc = RandomForestClassifier()
lr = LogisticRegression()
knc = KNeighborsClassifier()
svc = SVC()
dtc = DecisionTreeClassifier()
classification_models = [abc, bc, rfc, lr, knc, svc, dtc]
for model in classification_models:
    print(model)
    model.fit(X_train_sc, y_train)
    print(model.score(X_train_sc, y_train))
    print(model.score(X_test_sc, y_test))
# Out:
# AdaBoostClassifier()
# 0.5900506678949793
# 0.575849682232661
# BaggingClassifier()
# 0.9825886688162138
# 0.5413097540757115
# RandomForestClassifier()
# 0.9998157531091663
# 0.5772312793589389
# LogisticRegression()
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# 0.591524643021649
# 0.5788891959104725
# KNeighborsClassifier()
# 0.6428374021188392
# 0.5092567007460624
# SVC()
# 0.5988023952095808
# 0.5813760707377729
# DecisionTreeClassifier()
# ...

# %%
# DT / KN / RF / Bagging overfit - bad test scores - can work on gridsearching later

# %% [markdown]
# ### Dummy Country?

# %%
df_model['country'].value_counts()
# Out:
# United Kingdom           547
# France                   526
# Ireland                  428
# Germany                  360
# Kenya                    348
#                         ...
# Bhutan                     2
# Cape Verde                 2
# Serbia and Montenegro      2
# Qatar                      1
# South Sudan                1
# Name: country, Length: 166, dtype: int64

# %%
pd.set_option('display.max_rows', None)
df_model['country'].value_counts().to_frame()
# Out:
#                           country
# United Kingdom                547
# France                        526
# Ireland                       428
# Germany                       360
# Kenya                         348
# South Korea                   340
# Bangladesh                    336
# Venezuela                     314
# Greece                        308
# China                         263
# Thailand                      246
# Namibia                       225
# Brazil                        220
# Romania                       215
# Nepal                         206
# India                         203
# Russia                        192
# Pakistan                      172
# South Africa                  171
# Italy                         163
# Peru                          162
# Kyrgyzstan                    160
# Yemen                         157
# Chile                         156
# Spain                         155
# Nigeria                       150
# ...

# %%
# focus on countries wih over a certain number of protest

# %%
df_model['country'].value_counts().loc[lambda x: x>100] 
# create filter for columns where a country has more than 100 protests
# Out:
# United Kingdom    547
# France            526
# Ireland           428
# Germany           360
# Kenya             348
# South Korea       340
# Bangladesh        336
# Venezuela         314
# Greece            308
# China             263
# Thailand          246
# Namibia           225
# Brazil            220
# Romania           215
# Nepal             206
# India             203
# Russia            192
# Pakistan          172
# South Africa      171
# Italy             163
# Peru              162
# Kyrgyzstan        160
# Yemen             157
# Chile             156
# Spain             155
# Nigeria           150
# Ecuador           149
# Ukraine           148
# Indonesia         147
# Taiwan            147
# Malaysia          146
# Mexico            145
# Yugoslavia        137
# Colombia          134
# Bolivia           130
# Turkey            126
# Cyprus            125
# Azerbaijan        125
# Bulgaria          122
# Egypt             121
# Poland            117
# ...

# %% [markdown]
# ## Lasso / Ridge Logistic Regression

# %%
ridge_model = Ridge(alpha=10)

# %%
ridge_model.fit(X_train_sc, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-46588736db71> in <module>
# ----> 1 ridge_model.fit(X_train_sc, y_train)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/linear_model/_ridge.py in fit(self, X, y, sample_weight)
#     760         self : returns an instance of self.
#     761         """
# --> 762         return super().fit(X, y, sample_weight=sample_weight)
#     763
#     764
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/linear_model/_ridge.py in fit(self, X, y, sample_weight)
#     543                                    accept_sparse=_accept_sparse,
#     544                                    dtype=_dtype,
# --> 545                                    multi_output=True, y_numeric=True)
#     546         if sparse.issparse(X) and self.fit_intercept:
# ...
