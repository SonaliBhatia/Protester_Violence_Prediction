# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('../data/mmALL_073119_csv.csv')

# %%
df.head(-5)
# Out:
#                id           country  ccode  year         region  protest  \
# 0       201990001            Canada     20  1990  North America        1
# 1       201990002            Canada     20  1990  North America        1
# 2       201990003            Canada     20  1990  North America        1
# 3       201990004            Canada     20  1990  North America        1
# 4       201990005            Canada     20  1990  North America        1
# ...           ...               ...    ...   ...            ...      ...
# 16353  9102012003  Papua New Guinea    910  2012        Oceania        1
# 16354  9102013001  Papua New Guinea    910  2013        Oceania        1
# 16355  9102014001  Papua New Guinea    910  2014        Oceania        1
# 16356  9102015000  Papua New Guinea    910  2015        Oceania        0
# 16357  9102016001  Papua New Guinea    910  2016        Oceania        1
#
#        protestnumber  startday  startmonth  startyear  ...  protesterdemand4  \
# 0                  1      15.0         1.0     1990.0  ...               NaN
# 1                  2      25.0         6.0     1990.0  ...               NaN
# 2                  3       1.0         7.0     1990.0  ...               NaN
# 3                  4      12.0         7.0     1990.0  ...               NaN
# 4                  5      14.0         8.0     1990.0  ...               NaN
# ...              ...       ...         ...        ...  ...               ...
# 16353              3      10.0         4.0     2012.0  ...               NaN
# 16354              1       2.0         8.0     2013.0  ...               NaN
# 16355              1      16.0         2.0     2014.0  ...               NaN
# 16356              0       NaN         NaN        NaN  ...               NaN
# 16357              1      15.0         5.0     2016.0  ...               NaN
#
#         stateresponse1  stateresponse2   stateresponse3 stateresponse4  \
# 0               ignore             NaN              NaN            NaN
# 1               ignore             NaN              NaN            NaN
# 2               ignore             NaN              NaN            NaN
# 3         accomodation             NaN              NaN            NaN
# 4      crowd dispersal         arrests     accomodation            NaN
# ...                ...             ...              ...            ...
# 16353     accomodation             NaN              NaN            NaN
# 16354  crowd dispersal             NaN              NaN            NaN
# 16355  crowd dispersal       shootings              NaN            NaN
# 16356              NaN             NaN              NaN            NaN
# 16357        shootings        killings  crowd dispersal            NaN
#
#       stateresponse5 stateresponse6 stateresponse7  \
# 0                NaN            NaN            NaN
# 1                NaN            NaN            NaN
# 2                NaN            NaN            NaN
# 3                NaN            NaN            NaN
# 4                NaN            NaN            NaN
# ...              ...            ...            ...
# 16353            NaN            NaN            NaN
# 16354            NaN            NaN            NaN
# 16355            NaN            NaN            NaN
# 16356            NaN            NaN              .
# 16357            NaN            NaN            NaN
#
#                                                  sources  \
# 0      1. Great Canadian train journeys into history;...
# 1      1. Autonomy s Cry Revived in Quebec The New Yo...
# 2      1. Quebec protest after Queen calls for unity ...
# 3      1. Indians Gather as Siege Intensifies; Armed ...
# 4      1. Dozens hurt in Mohawk blockade protest The ...
# ...                                                  ...
# 16353   Protest forces PNG to stick to planned poll. ...
# 16354   PNG students oppose leaders  asylum deal.  We...
# 16355  Probe into killing of Manus detainee; MANUS IS...
# 16356                                                NaN
# 16357   Papua New Guinea: Reports of up to four peopl...
#
#                                                    notes
# 0       Canada s railway passenger system was finally...
# 1      protestors were only identified as  young peop...
# 2       THE Queen, after calling on Canadians to rema...
# 3       Canada s federal government has agreed to acq...
# 4      Protests were directed against the state due t...
# ...                                                  ...
# 16353  protesting against a proposed six month delay ...
# 16354  protesting gov ts deal w  Australia over asylu...
# 16355  ?  A government inquiry will be launched as se...
# 16356                                                NaN
# 16357  Police in Papua New Guinea fired gunshots Wedn...
#
# [16358 rows x 31 columns]

# %%
df.isnull().sum()
# Out:
# id                           0
# country                      0
# ccode                        0
# year                         0
# region                       0
# protest                      0
# protestnumber                0
# startday                  1849
# startmonth                1849
# startyear                 1849
# endday                    1849
# endmonth                  1849
# endyear                   1849
# protesterviolence         1330
# location                  1870
# participants_category     7203
# participants              1342
# protesteridentity         2404
# protesterdemand1          1860
# protesterdemand2         13687
# protesterdemand3         16047
# protesterdemand4         15467
# stateresponse1            1880
# stateresponse2           13647
# stateresponse3           15513
# stateresponse4           16133
# stateresponse5           15437
# stateresponse6           16347
# stateresponse7           15443
# sources                   1853
# notes                     1895
# dtype: int64

# %%
'''df['startday'].fillna(0,inplace=True)
df['startmonth'].fillna(0,inplace=True)

df['startyear'].fillna(0,inplace=True)'''

# %%
'''df['endday'].fillna(0,inplace=True)
df['endmonth'].fillna(0,inplace=True)
df['endyear'].fillna(0,inplace=True)'''

# %%
df.head()
# Out:
#           id country  ccode  year         region  protest  protestnumber  \
# 0  201990001  Canada     20  1990  North America        1              1
# 1  201990002  Canada     20  1990  North America        1              2
# 2  201990003  Canada     20  1990  North America        1              3
# 3  201990004  Canada     20  1990  North America        1              4
# 4  201990005  Canada     20  1990  North America        1              5
#
#    startday  startmonth  startyear  ...  protesterdemand4   stateresponse1  \
# 0      15.0         1.0     1990.0  ...               NaN           ignore
# 1      25.0         6.0     1990.0  ...               NaN           ignore
# 2       1.0         7.0     1990.0  ...               NaN           ignore
# 3      12.0         7.0     1990.0  ...               NaN     accomodation
# 4      14.0         8.0     1990.0  ...               NaN  crowd dispersal
#
#    stateresponse2  stateresponse3 stateresponse4 stateresponse5  \
# 0             NaN             NaN            NaN            NaN
# 1             NaN             NaN            NaN            NaN
# 2             NaN             NaN            NaN            NaN
# 3             NaN             NaN            NaN            NaN
# 4         arrests    accomodation            NaN            NaN
#
#   stateresponse6 stateresponse7  \
# 0            NaN            NaN
# 1            NaN            NaN
# 2            NaN            NaN
# 3            NaN            NaN
# 4            NaN            NaN
#
#                                              sources  \
# 0  1. Great Canadian train journeys into history;...
# 1  1. Autonomy s Cry Revived in Quebec The New Yo...
# 2  1. Quebec protest after Queen calls for unity ...
# 3  1. Indians Gather as Siege Intensifies; Armed ...
# 4  1. Dozens hurt in Mohawk blockade protest The ...
#
#                                                notes
# 0   Canada s railway passenger system was finally...
# 1  protestors were only identified as  young peop...
# 2   THE Queen, after calling on Canadians to rema...
# 3   Canada s federal government has agreed to acq...
# 4  Protests were directed against the state due t...
#
# [5 rows x 31 columns]

# %%
df.head()
# Out:
#           id country  ccode  year         region  protest  protestnumber  \
# 0  201990001  Canada     20  1990  North America        1              1
# 1  201990002  Canada     20  1990  North America        1              2
# 2  201990003  Canada     20  1990  North America        1              3
# 3  201990004  Canada     20  1990  North America        1              4
# 4  201990005  Canada     20  1990  North America        1              5
#
#    startday  startmonth  startyear  ...  protesterdemand4   stateresponse1  \
# 0      15.0         1.0     1990.0  ...               NaN           ignore
# 1      25.0         6.0     1990.0  ...               NaN           ignore
# 2       1.0         7.0     1990.0  ...               NaN           ignore
# 3      12.0         7.0     1990.0  ...               NaN     accomodation
# 4      14.0         8.0     1990.0  ...               NaN  crowd dispersal
#
#    stateresponse2  stateresponse3 stateresponse4 stateresponse5  \
# 0             NaN             NaN            NaN            NaN
# 1             NaN             NaN            NaN            NaN
# 2             NaN             NaN            NaN            NaN
# 3             NaN             NaN            NaN            NaN
# 4         arrests    accomodation            NaN            NaN
#
#   stateresponse6 stateresponse7  \
# 0            NaN            NaN
# 1            NaN            NaN
# 2            NaN            NaN
# 3            NaN            NaN
# 4            NaN            NaN
#
#                                              sources  \
# 0  1. Great Canadian train journeys into history;...
# 1  1. Autonomy s Cry Revived in Quebec The New Yo...
# 2  1. Quebec protest after Queen calls for unity ...
# 3  1. Indians Gather as Siege Intensifies; Armed ...
# 4  1. Dozens hurt in Mohawk blockade protest The ...
#
#                                                notes
# 0   Canada s railway passenger system was finally...
# 1  protestors were only identified as  young peop...
# 2   THE Queen, after calling on Canadians to rema...
# 3   Canada s federal government has agreed to acq...
# 4  Protests were directed against the state due t...
#
# [5 rows x 31 columns]

# %%
#df.drop(columns='startdate',inplace=True)

# %%
cols = ['startmonth', 'startday', 'startyear']
df['startdate'] = df[cols].apply(lambda row: '-'.join(row.values.astype(str)), axis=1)

# %%
df.head()
# Out:
#           id country  ccode  year         region  protest  protestnumber  \
# 0  201990001  Canada     20  1990  North America        1              1
# 1  201990002  Canada     20  1990  North America        1              2
# 2  201990003  Canada     20  1990  North America        1              3
# 3  201990004  Canada     20  1990  North America        1              4
# 4  201990005  Canada     20  1990  North America        1              5
#
#    startday  startmonth  startyear  ...   stateresponse1  stateresponse2  \
# 0      15.0         1.0     1990.0  ...           ignore             NaN
# 1      25.0         6.0     1990.0  ...           ignore             NaN
# 2       1.0         7.0     1990.0  ...           ignore             NaN
# 3      12.0         7.0     1990.0  ...     accomodation             NaN
# 4      14.0         8.0     1990.0  ...  crowd dispersal         arrests
#
#    stateresponse3  stateresponse4 stateresponse5 stateresponse6  \
# 0             NaN             NaN            NaN            NaN
# 1             NaN             NaN            NaN            NaN
# 2             NaN             NaN            NaN            NaN
# 3             NaN             NaN            NaN            NaN
# 4    accomodation             NaN            NaN            NaN
#
#   stateresponse7                                            sources  \
# 0            NaN  1. Great Canadian train journeys into history;...
# 1            NaN  1. Autonomy s Cry Revived in Quebec The New Yo...
# 2            NaN  1. Quebec protest after Queen calls for unity ...
# 3            NaN  1. Indians Gather as Siege Intensifies; Armed ...
# 4            NaN  1. Dozens hurt in Mohawk blockade protest The ...
#
#                                                notes        startdate
# 0   Canada s railway passenger system was finally...  1.0-15.0-1990.0
# 1  protestors were only identified as  young peop...  6.0-25.0-1990.0
# 2   THE Queen, after calling on Canadians to rema...   7.0-1.0-1990.0
# 3   Canada s federal government has agreed to acq...  7.0-12.0-1990.0
# 4  Protests were directed against the state due t...  8.0-14.0-1990.0
#
# [5 rows x 32 columns]

# %%
df['startdate']=df['startdate'].str.replace('\.0','')

# %%
df['startdate']
# Out:
# 0          1-15-1990
# 1          6-25-1990
# 2           7-1-1990
# 3          7-12-1990
# 4          8-14-1990
#             ...
# 16358      6-15-2017
# 16359      7-15-2017
# 16360     10-31-2017
# 16361    nan-nan-nan
# 16362    nan-nan-nan
# Name: startdate, Length: 16363, dtype: object

# %%
df.tail(5)
# Out:
#                id           country  ccode  year   region  protest  \
# 16358  9102017001  Papua New Guinea    910  2017  Oceania        1
# 16359  9102017002  Papua New Guinea    910  2017  Oceania        1
# 16360  9102017003  Papua New Guinea    910  2017  Oceania        1
# 16361  9102018000  Papua New Guinea    910  2018  Oceania        0
# 16362  9102019000  Papua New Guinea    910  2019  Oceania        0
#
#        protestnumber  startday  startmonth  startyear  ...   stateresponse1  \
# 16358              1      15.0         6.0     2017.0  ...     accomodation
# 16359              2      15.0         7.0     2017.0  ...  crowd dispersal
# 16360              3      31.0        10.0     2017.0  ...           ignore
# 16361              0       NaN         NaN        NaN  ...              NaN
# 16362              0       NaN         NaN        NaN  ...              NaN
#
#        stateresponse2  stateresponse3  stateresponse4 stateresponse5  \
# 16358             NaN             NaN             NaN            NaN
# 16359             NaN             NaN             NaN            NaN
# 16360             NaN             NaN             NaN            NaN
# 16361             NaN             NaN             NaN            NaN
# 16362             NaN             NaN             NaN              .
#
#       stateresponse6 stateresponse7  \
# 16358            NaN            NaN
# 16359            NaN            NaN
# 16360            NaN            NaN
# 16361            NaN            NaN
# 16362            NaN            NaN
#
#                                                  sources  \
# 16358   Bougainville imposes moratorium on Panguna mi...
# 16359   Violence, chaos and fraud: fraught Papua New ...
# 16360   Refugees dig in as camp closes; Manus   Situa...
# 16361                                                NaN
# 16362                                                NaN
#
#                                                    notes    startdate
# 16358  The Bougainville government has enacted an ind...    6-15-2017
# 16359  Peter O Neill has been reappointed as prime mi...    7-15-2017
# 16360  Refugees on Manus Island were braced for poten...   10-31-2017
# 16361                                                NaN  nan-nan-nan
# 16362                                                NaN  nan-nan-nan
#
# [5 rows x 32 columns]

# %%
df=df[df['startdate']!='nan-nan-nan']

# %%
df['startdate']
# Out:
# 0         1-15-1990
# 1         6-25-1990
# 2          7-1-1990
# 3         7-12-1990
# 4         8-14-1990
#             ...
# 16355     2-16-2014
# 16357     5-15-2016
# 16358     6-15-2017
# 16359     7-15-2017
# 16360    10-31-2017
# Name: startdate, Length: 14514, dtype: object

# %%
df['startdate']=pd.to_datetime(df['startdate'])

# %%
df['startdate']
# Out:
# 0       1990-01-15
# 1       1990-06-25
# 2       1990-07-01
# 3       1990-07-12
# 4       1990-08-14
#            ...
# 16355   2014-02-16
# 16357   2016-05-15
# 16358   2017-06-15
# 16359   2017-07-15
# 16360   2017-10-31
# Name: startdate, Length: 14514, dtype: datetime64[ns]

# %%
cols=['endmonth','endday','endyear']
df['enddate'] = df[cols].apply(lambda row: '-'.join(row.values.astype(str)), axis=1)

# %%
df['enddate']
# Out:
# 0         1.0-15.0-1990.0
# 1         6.0-25.0-1990.0
# 2          7.0-1.0-1990.0
# 3          9.0-6.0-1990.0
# 4         8.0-15.0-1990.0
#                ...
# 16355     2.0-18.0-2014.0
# 16357      6.0-9.0-2016.0
# 16358     6.0-15.0-2017.0
# 16359     7.0-15.0-2017.0
# 16360    10.0-31.0-2017.0
# Name: enddate, Length: 14514, dtype: object

# %%
df['enddate']=df['enddate'].str.replace('\.0','')

# %%
df['enddate']
# Out:
# 0         1-15-1990
# 1         6-25-1990
# 2          7-1-1990
# 3          9-6-1990
# 4         8-15-1990
#             ...
# 16355     2-18-2014
# 16357      6-9-2016
# 16358     6-15-2017
# 16359     7-15-2017
# 16360    10-31-2017
# Name: enddate, Length: 14514, dtype: object

# %%
df['enddate']=pd.to_datetime(df['enddate'])

# %%
df['enddate']
# Out:
# 0       1990-01-15
# 1       1990-06-25
# 2       1990-07-01
# 3       1990-09-06
# 4       1990-08-15
#            ...
# 16355   2014-02-18
# 16357   2016-06-09
# 16358   2017-06-15
# 16359   2017-07-15
# 16360   2017-10-31
# Name: enddate, Length: 14514, dtype: datetime64[ns]

# %%
df['duration']=df['enddate']-df['startdate']

# %%
df['duration'].sort_values(ascending=False)
# Out:
# 11631   938 days
# 14531   731 days
# 6150    658 days
# 12431   626 days
# 2488    367 days
#           ...
# 10127     0 days
# 10126     0 days
# 10125     0 days
# 10124     0 days
# 0         0 days
# Name: duration, Length: 14514, dtype: timedelta64[ns]

# %%
df.columns
# Out:
# Index(['id', 'country', 'ccode', 'year', 'region', 'protest', 'protestnumber',
#        'startday', 'startmonth', 'startyear', 'endday', 'endmonth', 'endyear',
#        'protesterviolence', 'location', 'participants_category',
#        'participants', 'protesteridentity', 'protesterdemand1',
#        'protesterdemand2', 'protesterdemand3', 'protesterdemand4',
#        'stateresponse1', 'stateresponse2', 'stateresponse3', 'stateresponse4',
#        'stateresponse5', 'stateresponse6', 'stateresponse7', 'sources',
#        'notes', 'startdate', 'enddate', 'duration'],
#       dtype='object')

# %%
df.drop(columns=['ccode','id','location','participants_category','protesteridentity','sources'],inplace=True)

# %%
df.head()
# Out:
#   country  year         region  protest  protestnumber  startday  startmonth  \
# 0  Canada  1990  North America        1              1      15.0         1.0
# 1  Canada  1990  North America        1              2      25.0         6.0
# 2  Canada  1990  North America        1              3       1.0         7.0
# 3  Canada  1990  North America        1              4      12.0         7.0
# 4  Canada  1990  North America        1              5      14.0         8.0
#
#    startyear  endday  endmonth  ...  stateresponse2  stateresponse3  \
# 0     1990.0    15.0       1.0  ...             NaN             NaN
# 1     1990.0    25.0       6.0  ...             NaN             NaN
# 2     1990.0     1.0       7.0  ...             NaN             NaN
# 3     1990.0     6.0       9.0  ...             NaN             NaN
# 4     1990.0    15.0       8.0  ...         arrests    accomodation
#
#   stateresponse4 stateresponse5 stateresponse6 stateresponse7  \
# 0            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN
#
#                                                notes  startdate    enddate  \
# 0   Canada s railway passenger system was finally... 1990-01-15 1990-01-15
# 1  protestors were only identified as  young peop... 1990-06-25 1990-06-25
# 2   THE Queen, after calling on Canadians to rema... 1990-07-01 1990-07-01
# 3   Canada s federal government has agreed to acq... 1990-07-12 1990-09-06
# 4  Protests were directed against the state due t... 1990-08-14 1990-08-15
#
#   duration
# 0   0 days
# 1   0 days
# 2   0 days
# 3  56 days
# 4   1 days
#
# [5 rows x 28 columns]

# %%
df['startyear'].value_counts().plot(kind='bar',figsize=(15,15),title='No of protests by year')

# %%
duplicates=df.duplicated()

# %%
print(duplicates.sum())
df[duplicates]
# Out:
# 0
# Empty DataFrame
# Columns: [country, year, region, protest, protestnumber, startday, startmonth, startyear, endday, endmonth, endyear, protesterviolence, participants, protesterdemand1, protesterdemand2, protesterdemand3, protesterdemand4, stateresponse1, stateresponse2, stateresponse3, stateresponse4, stateresponse5, stateresponse6, stateresponse7, notes, startdate, enddate, duration]
# Index: []
#
# [0 rows x 28 columns]

# %%
df['startdate'].value_counts()
# Out:
# 2014-01-24    16
# 2017-05-01    13
# 2002-05-01    10
# 2012-05-01    10
# 2018-05-01    10
#               ..
# 2000-10-25     1
# 2008-10-22     1
# 2009-12-13     1
# 2013-12-30     1
# 1991-09-11     1
# Name: startdate, Length: 7533, dtype: int64

# %%
df['country'].value_counts().plot(kind='bar',figsize=(25 , 20),title='No of protests by country')

# %%
df['stateresponse1'].value_counts().plot(kind='barh',figsize=(15,10),title='Counts per state response');
